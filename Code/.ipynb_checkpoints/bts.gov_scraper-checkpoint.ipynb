# %%
POST = '''UserTableName=On_Time_Performance&DBShortName=On_Time&RawDataTable=T_ONTIME&sqlstr=+SELECT+YEAR,MONTH,DAY_OF_MONTH,DAY_OF_WEEK,FL_DATE,UNIQUE_CARRIER,TAIL_NUM,FL_NUM,ORIGIN_AIRPORT_ID,ORIGIN_CITY_MARKET_ID,DEST_AIRPORT_ID,DEST_CITY_MARKET_ID,CRS_DEP_TIME,DEP_TIME,DEP_DELAY_NEW,TAXI_OUT,WHEELS_OFF,WHEELS_ON,TAXI_IN,CRS_ARR_TIME,ARR_TIME,ARR_DELAY_NEW,CANCELLED,CANCELLATION_CODE,CRS_ELAPSED_TIME,ACTUAL_ELAPSED_TIME,AIR_TIME,FLIGHTS,DISTANCE,CARRIER_DELAY,WEATHER_DELAY,NAS_DELAY,SECURITY_DELAY,LATE_AIRCRAFT_DELAY+FROM+T_ONTIME+WHERE+(DEST_STATE_NM='{state}'+OR+ORIGIN_STATE_NM='{state}')+AND+Month+={month_num}+AND+YEAR={year}&varlist=YEAR,MONTH,DAY_OF_MONTH,DAY_OF_WEEK,FL_DATE,UNIQUE_CARRIER,TAIL_NUM,FL_NUM,ORIGIN_AIRPORT_ID,ORIGIN_CITY_MARKET_ID,DEST_AIRPORT_ID,DEST_CITY_MARKET_ID,CRS_DEP_TIME,DEP_TIME,DEP_DELAY_NEW,TAXI_OUT,WHEELS_OFF,WHEELS_ON,TAXI_IN,CRS_ARR_TIME,ARR_TIME,ARR_DELAY_NEW,CANCELLED,CANCELLATION_CODE,CRS_ELAPSED_TIME,ACTUAL_ELAPSED_TIME,AIR_TIME,FLIGHTS,DISTANCE,CARRIER_DELAY,WEATHER_DELAY,NAS_DELAY,SECURITY_DELAY,LATE_AIRCRAFT_DELAY&grouplist=&suml=&sumRegion=&filter1=title=&filter2=title=&geo=All&time={month}&timename=Month&GEOGRAPHY={state}&XYEAR={year}&FREQUENCY={frequency}&VarName=YEAR&VarDesc=Year&VarType=Num&VarDesc=Quarter&VarType=Num&VarName=MONTH&VarDesc=Month&VarType=Num&VarName=DAY_OF_MONTH&VarDesc=DayofMonth&VarType=Num&VarName=DAY_OF_WEEK&VarDesc=DayOfWeek&VarType=Num&VarName=FL_DATE&VarDesc=FlightDate&VarType=Char&VarName=UNIQUE_CARRIER&VarDesc=UniqueCarrier&VarType=Char&VarDesc=AirlineID&VarType=Num&VarDesc=Carrier&VarType=Char&VarName=TAIL_NUM&VarDesc=TailNum&VarType=Char&VarName=FL_NUM&VarDesc=FlightNum&VarType=Char&VarName=ORIGIN_AIRPORT_ID&VarDesc=OriginAirportID&VarType=Num&VarDesc=OriginAirportSeqID&VarType=Num&VarName=ORIGIN_CITY_MARKET_ID&VarDesc=OriginCityMarketID&VarType=Num&VarDesc=Origin&VarType=Char&VarDesc=OriginCityName&VarType=Char&VarDesc=OriginState&VarType=Char&VarDesc=OriginStateFips&VarType=Char&VarDesc=OriginStateName&VarType=Char&VarDesc=OriginWac&VarType=Num&VarName=DEST_AIRPORT_ID&VarDesc=DestAirportID&VarType=Num&VarDesc=DestAirportSeqID&VarType=Num&VarName=DEST_CITY_MARKET_ID&VarDesc=DestCityMarketID&VarType=Num&VarDesc=Dest&VarType=Char&VarDesc=DestCityName&VarType=Char&VarDesc=DestState&VarType=Char&VarDesc=DestStateFips&VarType=Char&VarDesc=DestStateName&VarType=Char&VarDesc=DestWac&VarType=Num&VarName=CRS_DEP_TIME&VarDesc=CRSDepTime&VarType=Char&VarName=DEP_TIME&VarDesc=DepTime&VarType=Char&VarDesc=DepDelay&VarType=Num&VarName=DEP_DELAY_NEW&VarDesc=DepDelayMinutes&VarType=Num&VarDesc=DepDel15&VarType=Num&VarDesc=DepartureDelayGroups&VarType=Num&VarDesc=DepTimeBlk&VarType=Char&VarName=TAXI_OUT&VarDesc=TaxiOut&VarType=Num&VarName=WHEELS_OFF&VarDesc=WheelsOff&VarType=Char&VarName=WHEELS_ON&VarDesc=WheelsOn&VarType=Char&VarName=TAXI_IN&VarDesc=TaxiIn&VarType=Num&VarName=CRS_ARR_TIME&VarDesc=CRSArrTime&VarType=Char&VarName=ARR_TIME&VarDesc=ArrTime&VarType=Char&VarDesc=ArrDelay&VarType=Num&VarName=ARR_DELAY_NEW&VarDesc=ArrDelayMinutes&VarType=Num&VarDesc=ArrDel15&VarType=Num&VarDesc=ArrivalDelayGroups&VarType=Num&VarDesc=ArrTimeBlk&VarType=Char&VarName=CANCELLED&VarDesc=Cancelled&VarType=Num&VarName=CANCELLATION_CODE&VarDesc=CancellationCode&VarType=Char&VarDesc=Diverted&VarType=Num&VarName=CRS_ELAPSED_TIME&VarDesc=CRSElapsedTime&VarType=Num&VarName=ACTUAL_ELAPSED_TIME&VarDesc=ActualElapsedTime&VarType=Num&VarName=AIR_TIME&VarDesc=AirTime&VarType=Num&VarName=FLIGHTS&VarDesc=Flights&VarType=Num&VarName=DISTANCE&VarDesc=Distance&VarType=Num&VarDesc=DistanceGroup&VarType=Num&VarName=CARRIER_DELAY&VarDesc=CarrierDelay&VarType=Num&VarName=WEATHER_DELAY&VarDesc=WeatherDelay&VarType=Num&VarName=NAS_DELAY&VarDesc=NASDelay&VarType=Num&VarName=SECURITY_DELAY&VarDesc=SecurityDelay&VarType=Num&VarName=LATE_AIRCRAFT_DELAY&VarDesc=LateAircraftDelay&VarType=Num&VarDesc=FirstDepTime&VarType=Char&VarDesc=TotalAddGTime&VarType=Num&VarDesc=LongestAddGTime&VarType=Num&VarDesc=DivAirportLandings&VarType=Num&VarDesc=DivReachedDest&VarType=Num&VarDesc=DivActualElapsedTime&VarType=Num&VarDesc=DivArrDelay&VarType=Num&VarDesc=DivDistance&VarType=Num&VarDesc=Div1Airport&VarType=Char&VarDesc=Div1AirportID&VarType=Num&VarDesc=Div1AirportSeqID&VarType=Num&VarDesc=Div1WheelsOn&VarType=Char&VarDesc=Div1TotalGTime&VarType=Num&VarDesc=Div1LongestGTime&VarType=Num&VarDesc=Div1WheelsOff&VarType=Char&VarDesc=Div1TailNum&VarType=Char&VarDesc=Div2Airport&VarType=Char&VarDesc=Div2AirportID&VarType=Num&VarDesc=Div2AirportSeqID&VarType=Num&VarDesc=Div2WheelsOn&VarType=Char&VarDesc=Div2TotalGTime&VarType=Num&VarDesc=Div2LongestGTime&VarType=Num&VarDesc=Div2WheelsOff&VarType=Char&VarDesc=Div2TailNum&VarType=Char&VarDesc=Div3Airport&VarType=Char&VarDesc=Div3AirportID&VarType=Num&VarDesc=Div3AirportSeqID&VarType=Num&VarDesc=Div3WheelsOn&VarType=Char&VarDesc=Div3TotalGTime&VarType=Num&VarDesc=Div3LongestGTime&VarType=Num&VarDesc=Div3WheelsOff&VarType=Char&VarDesc=Div3TailNum&VarType=Char&VarDesc=Div4Airport&VarType=Char&VarDesc=Div4AirportID&VarType=Num&VarDesc=Div4AirportSeqID&VarType=Num&VarDesc=Div4WheelsOn&VarType=Char&VarDesc=Div4TotalGTime&VarType=Num&VarDesc=Div4LongestGTime&VarType=Num&VarDesc=Div4WheelsOff&VarType=Char&VarDesc=Div4TailNum&VarType=Char&VarDesc=Div5Airport&VarType=Char&VarDesc=Div5AirportID&VarType=Num&VarDesc=Div5AirportSeqID&VarType=Num&VarDesc=Div5WheelsOn&VarType=Char&VarDesc=Div5TotalGTime&VarType=Num&VarDesc=Div5LongestGTime&VarType=Num&VarDesc=Div5WheelsOff&VarType=Char&VarDesc=Div5TailNum&VarType=Char'''

# %%
months = range(1,13)
years = range(2011, 2017)
max_date = [2016,7]

def year_month(years, months, max_date):
    lst = []
    for year in years:
        for month in months:
            if year >= max_date[0] and month > max_date[1]:
                return lst
            else:
                lst.append([year, month])
    return lst

dates = year_month(years, months, max_date)

# %%
import datetime
from os import rename
from os.path import splitext
from calendar import month_name
from httplib import HTTPConnection
from time import clock
from urllib import urlretrieve
from zipfile import ZipFile

def scrape_airport(dates, state, POST):
    'downloads and unzips data from bts described in post'
    host = "www.transtats.bts.gov"
    url = "http://{host}/DownLoad_Table.asp?" + \
                   "Table_ID=236&Has_Group=3&Is_Zipped=0"
    frequency = 1
    for date in dates:
        year = date[0]
        month = date[1]
        
        # setup the POST
        post = POST.format(year=year, month=month_name[month], month_num=month,
                           state=state, frequency=frequency)
        # make sure post has no EOLs
        post = post.replace('\n','')

        # create the user agent string, and emulate a browser
        user_agent_string = {
            "Content-Type" : "application/x-www-form-urlencoded",
            }

        # make a friendly name for the output file
        output_file = '{0}-{1}'.format(year, str(month).zfill(2))
        zip_file_name = '{}.zip'.format(output_file)
        csv_file_name = '{}.csv'.format(output_file)

        # now collect data
        print "Collecting RITA data for {0}, {1}".format(year, month_name[month])

        # lets get some data, create the request string
        request = HTTPConnection(host)

        # set up the url
        url = url.format(host=host)
        print "Sending POST to {}".format(host)

        # keep track of the time, see how long it takes
        tic = clock()
        request.request("POST", url, post, user_agent_string)

        
        print "get the response from the POST"
        response = request.getresponse()

        if not response.status == 302:
            raise Exception("Request was not successful with response {}".format(
                response.status
                ))

        # get location from headers
        remote_file = response.getheader('location')

        local_file = urlretrieve(remote_file, zip_file_name)

        print "Downloaded: {} in {} seconds".format(zip_file_name, clock()-tic)
        print local_file
        
        # now unzip the file
        print "Unzipping {}".format(zip_file_name)
        z = ZipFile(zip_file_name)

        # extract the csv file from the zip
        for zip_file in z.namelist():
            if splitext(zip_file)[-1] != '.csv': continue
            z.extract(zip_file)
            rename(zip_file, csv_file_name)
            print "RITA file is: {}".format(csv_file_name)
            break

# %%
scrape_airport(dates, 'Illinois', POST)
# Out:
# 2011
# 1
# Collecting RITA data for 2011, January
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-01.zip in 0.082707 seconds
# ('2011-01.zip', <httplib.HTTPMessage instance at 0x103ea3050>)
# Unzipping 2011-01.zip
# RITA file is: 2011-01.csv
# 2011
# 2
# Collecting RITA data for 2011, February
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-02.zip in 0.072001 seconds
# ('2011-02.zip', <httplib.HTTPMessage instance at 0x1044d2b48>)
# Unzipping 2011-02.zip
# RITA file is: 2011-02.csv
# 2011
# 3
# Collecting RITA data for 2011, March
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-03.zip in 0.085914 seconds
# ('2011-03.zip', <httplib.HTTPMessage instance at 0x1044c2878>)
# Unzipping 2011-03.zip
# RITA file is: 2011-03.csv
# 2011
# 4
# Collecting RITA data for 2011, April
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-04.zip in 0.0544 seconds
# ('2011-04.zip', <httplib.HTTPMessage instance at 0x1044d20e0>)
# Unzipping 2011-04.zip
# RITA file is: 2011-04.csv
# 2011
# 5
# Collecting RITA data for 2011, May
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-05.zip in 0.073056 seconds
# ('2011-05.zip', <httplib.HTTPMessage instance at 0x1044c2908>)
# Unzipping 2011-05.zip
# RITA file is: 2011-05.csv
# 2011
# 6
# Collecting RITA data for 2011, June
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-06.zip in 0.074875 seconds
# ('2011-06.zip', <httplib.HTTPMessage instance at 0x1044d2128>)
# Unzipping 2011-06.zip
# RITA file is: 2011-06.csv
# 2011
# 7
# Collecting RITA data for 2011, July
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-07.zip in 0.07772 seconds
# ('2011-07.zip', <httplib.HTTPMessage instance at 0x1044d2320>)
# Unzipping 2011-07.zip
# RITA file is: 2011-07.csv
# 2011
# 8
# Collecting RITA data for 2011, August
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-08.zip in 0.078963 seconds
# ('2011-08.zip', <httplib.HTTPMessage instance at 0x1044d2b48>)
# Unzipping 2011-08.zip
# RITA file is: 2011-08.csv
# 2011
# 9
# Collecting RITA data for 2011, September
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-09.zip in 0.063507 seconds
# ('2011-09.zip', <httplib.HTTPMessage instance at 0x1044d2320>)
# Unzipping 2011-09.zip
# RITA file is: 2011-09.csv
# 2011
# 10
# Collecting RITA data for 2011, October
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-10.zip in 0.073256 seconds
# ('2011-10.zip', <httplib.HTTPMessage instance at 0x1044d2248>)
# Unzipping 2011-10.zip
# RITA file is: 2011-10.csv
# 2011
# 11
# Collecting RITA data for 2011, November
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-11.zip in 0.064027 seconds
# ('2011-11.zip', <httplib.HTTPMessage instance at 0x1044d2a70>)
# Unzipping 2011-11.zip
# RITA file is: 2011-11.csv
# 2011
# 12
# Collecting RITA data for 2011, December
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2011-12.zip in 0.064743 seconds
# ('2011-12.zip', <httplib.HTTPMessage instance at 0x1044d2c20>)
# Unzipping 2011-12.zip
# RITA file is: 2011-12.csv
# 2012
# 1
# Collecting RITA data for 2012, January
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-01.zip in 0.057823 seconds
# ('2012-01.zip', <httplib.HTTPMessage instance at 0x1044d2cf8>)
# Unzipping 2012-01.zip
# RITA file is: 2012-01.csv
# 2012
# 2
# Collecting RITA data for 2012, February
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-02.zip in 0.063556 seconds
# ('2012-02.zip', <httplib.HTTPMessage instance at 0x1044d20e0>)
# Unzipping 2012-02.zip
# RITA file is: 2012-02.csv
# 2012
# 3
# Collecting RITA data for 2012, March
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-03.zip in 0.09052 seconds
# ('2012-03.zip', <httplib.HTTPMessage instance at 0x10458abd8>)
# Unzipping 2012-03.zip
# RITA file is: 2012-03.csv
# 2012
# 4
# Collecting RITA data for 2012, April
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-04.zip in 0.072415 seconds
# ('2012-04.zip', <httplib.HTTPMessage instance at 0x1044d20e0>)
# Unzipping 2012-04.zip
# RITA file is: 2012-04.csv
# 2012
# 5
# Collecting RITA data for 2012, May
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-05.zip in 0.079441 seconds
# ('2012-05.zip', <httplib.HTTPMessage instance at 0x10458af80>)
# Unzipping 2012-05.zip
# RITA file is: 2012-05.csv
# 2012
# 6
# Collecting RITA data for 2012, June
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-06.zip in 0.064194 seconds
# ('2012-06.zip', <httplib.HTTPMessage instance at 0x104569050>)
# Unzipping 2012-06.zip
# RITA file is: 2012-06.csv
# 2012
# 7
# Collecting RITA data for 2012, July
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-07.zip in 0.063868 seconds
# ('2012-07.zip', <httplib.HTTPMessage instance at 0x1044d2170>)
# Unzipping 2012-07.zip
# RITA file is: 2012-07.csv
# 2012
# 8
# Collecting RITA data for 2012, August
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-08.zip in 0.064511 seconds
# ('2012-08.zip', <httplib.HTTPMessage instance at 0x1044c2830>)
# Unzipping 2012-08.zip
# RITA file is: 2012-08.csv
# 2012
# 9
# Collecting RITA data for 2012, September
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-09.zip in 0.057515 seconds
# ('2012-09.zip', <httplib.HTTPMessage instance at 0x104569050>)
# Unzipping 2012-09.zip
# RITA file is: 2012-09.csv
# 2012
# 10
# Collecting RITA data for 2012, October
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-10.zip in 0.098148 seconds
# ('2012-10.zip', <httplib.HTTPMessage instance at 0x1044d2ab8>)
# Unzipping 2012-10.zip
# RITA file is: 2012-10.csv
# 2012
# 11
# Collecting RITA data for 2012, November
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-11.zip in 0.044418 seconds
# ('2012-11.zip', <httplib.HTTPMessage instance at 0x1044d2a70>)
# Unzipping 2012-11.zip
# RITA file is: 2012-11.csv
# 2012
# 12
# Collecting RITA data for 2012, December
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2012-12.zip in 0.065394 seconds
# ('2012-12.zip', <httplib.HTTPMessage instance at 0x1045692d8>)
# Unzipping 2012-12.zip
# RITA file is: 2012-12.csv
# 2013
# 1
# Collecting RITA data for 2013, January
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-01.zip in 0.059292 seconds
# ('2013-01.zip', <httplib.HTTPMessage instance at 0x10458ab48>)
# Unzipping 2013-01.zip
# RITA file is: 2013-01.csv
# 2013
# 2
# Collecting RITA data for 2013, February
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-02.zip in 0.048098 seconds
# ('2013-02.zip', <httplib.HTTPMessage instance at 0x10458ab90>)
# Unzipping 2013-02.zip
# RITA file is: 2013-02.csv
# 2013
# 3
# Collecting RITA data for 2013, March
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-03.zip in 0.071722 seconds
# ('2013-03.zip', <httplib.HTTPMessage instance at 0x1044d2248>)
# Unzipping 2013-03.zip
# RITA file is: 2013-03.csv
# 2013
# 4
# Collecting RITA data for 2013, April
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-04.zip in 0.074955 seconds
# ('2013-04.zip', <httplib.HTTPMessage instance at 0x10458ab48>)
# Unzipping 2013-04.zip
# RITA file is: 2013-04.csv
# 2013
# 5
# Collecting RITA data for 2013, May
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-05.zip in 0.055001 seconds
# ('2013-05.zip', <httplib.HTTPMessage instance at 0x10452ff38>)
# Unzipping 2013-05.zip
# RITA file is: 2013-05.csv
# 2013
# 6
# Collecting RITA data for 2013, June
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-06.zip in 0.062602 seconds
# ('2013-06.zip', <httplib.HTTPMessage instance at 0x1044c2878>)
# Unzipping 2013-06.zip
# RITA file is: 2013-06.csv
# 2013
# 7
# Collecting RITA data for 2013, July
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-07.zip in 0.066684 seconds
# ('2013-07.zip', <httplib.HTTPMessage instance at 0x1044d20e0>)
# Unzipping 2013-07.zip
# RITA file is: 2013-07.csv
# 2013
# 8
# Collecting RITA data for 2013, August
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-08.zip in 0.070436 seconds
# ('2013-08.zip', <httplib.HTTPMessage instance at 0x10458aef0>)
# Unzipping 2013-08.zip
# RITA file is: 2013-08.csv
# 2013
# 9
# Collecting RITA data for 2013, September
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-09.zip in 0.070435 seconds
# ('2013-09.zip', <httplib.HTTPMessage instance at 0x1044d2b48>)
# Unzipping 2013-09.zip
# RITA file is: 2013-09.csv
# 2013
# 10
# Collecting RITA data for 2013, October
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-10.zip in 0.062462 seconds
# ('2013-10.zip', <httplib.HTTPMessage instance at 0x104569050>)
# Unzipping 2013-10.zip
# RITA file is: 2013-10.csv
# 2013
# 11
# Collecting RITA data for 2013, November
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-11.zip in 0.063634 seconds
# ('2013-11.zip', <httplib.HTTPMessage instance at 0x1044d2a70>)
# Unzipping 2013-11.zip
# RITA file is: 2013-11.csv
# 2013
# 12
# Collecting RITA data for 2013, December
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2013-12.zip in 0.053419 seconds
# ('2013-12.zip', <httplib.HTTPMessage instance at 0x10458ae18>)
# Unzipping 2013-12.zip
# RITA file is: 2013-12.csv
# 2014
# 1
# Collecting RITA data for 2014, January
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-01.zip in 0.061705 seconds
# ('2014-01.zip', <httplib.HTTPMessage instance at 0x1044d2a70>)
# Unzipping 2014-01.zip
# RITA file is: 2014-01.csv
# 2014
# 2
# Collecting RITA data for 2014, February
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-02.zip in 0.044014 seconds
# ('2014-02.zip', <httplib.HTTPMessage instance at 0x1044d2170>)
# Unzipping 2014-02.zip
# RITA file is: 2014-02.csv
# 2014
# 3
# Collecting RITA data for 2014, March
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-03.zip in 0.061004 seconds
# ('2014-03.zip', <httplib.HTTPMessage instance at 0x10458abd8>)
# Unzipping 2014-03.zip
# RITA file is: 2014-03.csv
# 2014
# 4
# Collecting RITA data for 2014, April
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-04.zip in 0.059869 seconds
# ('2014-04.zip', <httplib.HTTPMessage instance at 0x1034d0f80>)
# Unzipping 2014-04.zip
# RITA file is: 2014-04.csv
# 2014
# 5
# Collecting RITA data for 2014, May
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-05.zip in 0.07789 seconds
# ('2014-05.zip', <httplib.HTTPMessage instance at 0x1044d20e0>)
# Unzipping 2014-05.zip
# RITA file is: 2014-05.csv
# 2014
# 6
# Collecting RITA data for 2014, June
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-06.zip in 0.066897 seconds
# ('2014-06.zip', <httplib.HTTPMessage instance at 0x1044d2248>)
# Unzipping 2014-06.zip
# RITA file is: 2014-06.csv
# 2014
# 7
# Collecting RITA data for 2014, July
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-07.zip in 0.051415 seconds
# ('2014-07.zip', <httplib.HTTPMessage instance at 0x1044d2128>)
# Unzipping 2014-07.zip
# RITA file is: 2014-07.csv
# 2014
# 8
# Collecting RITA data for 2014, August
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-08.zip in 0.075941 seconds
# ('2014-08.zip', <httplib.HTTPMessage instance at 0x10458aef0>)
# Unzipping 2014-08.zip
# RITA file is: 2014-08.csv
# 2014
# 9
# Collecting RITA data for 2014, September
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-09.zip in 0.055774 seconds
# ('2014-09.zip', <httplib.HTTPMessage instance at 0x1044d2ab8>)
# Unzipping 2014-09.zip
# RITA file is: 2014-09.csv
# 2014
# 10
# Collecting RITA data for 2014, October
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-10.zip in 0.048284 seconds
# ('2014-10.zip', <httplib.HTTPMessage instance at 0x1044d2170>)
# Unzipping 2014-10.zip
# RITA file is: 2014-10.csv
# 2014
# 11
# Collecting RITA data for 2014, November
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-11.zip in 0.046666 seconds
# ('2014-11.zip', <httplib.HTTPMessage instance at 0x10458aef0>)
# Unzipping 2014-11.zip
# RITA file is: 2014-11.csv
# 2014
# 12
# Collecting RITA data for 2014, December
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2014-12.zip in 0.070135 seconds
# ('2014-12.zip', <httplib.HTTPMessage instance at 0x1045698c0>)
# Unzipping 2014-12.zip
# RITA file is: 2014-12.csv
# 2015
# 1
# Collecting RITA data for 2015, January
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-01.zip in 0.070615 seconds
# ('2015-01.zip', <httplib.HTTPMessage instance at 0x1044d2170>)
# Unzipping 2015-01.zip
# RITA file is: 2015-01.csv
# 2015
# 2
# Collecting RITA data for 2015, February
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-02.zip in 0.054303 seconds
# ('2015-02.zip', <httplib.HTTPMessage instance at 0x1044c2908>)
# Unzipping 2015-02.zip
# RITA file is: 2015-02.csv
# 2015
# 3
# Collecting RITA data for 2015, March
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-03.zip in 0.066913 seconds
# ('2015-03.zip', <httplib.HTTPMessage instance at 0x1044d2a28>)
# Unzipping 2015-03.zip
# RITA file is: 2015-03.csv
# 2015
# 4
# Collecting RITA data for 2015, April
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-04.zip in 0.056128 seconds
# ('2015-04.zip', <httplib.HTTPMessage instance at 0x1045697a0>)
# Unzipping 2015-04.zip
# RITA file is: 2015-04.csv
# 2015
# 5
# Collecting RITA data for 2015, May
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-05.zip in 0.057884 seconds
# ('2015-05.zip', <httplib.HTTPMessage instance at 0x1044d2320>)
# Unzipping 2015-05.zip
# RITA file is: 2015-05.csv
# 2015
# 6
# Collecting RITA data for 2015, June
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-06.zip in 0.060876 seconds
# ('2015-06.zip', <httplib.HTTPMessage instance at 0x1044d2128>)
# Unzipping 2015-06.zip
# RITA file is: 2015-06.csv
# 2015
# 7
# Collecting RITA data for 2015, July
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-07.zip in 0.0731 seconds
# ('2015-07.zip', <httplib.HTTPMessage instance at 0x1044d2ab8>)
# Unzipping 2015-07.zip
# RITA file is: 2015-07.csv
# 2015
# 8
# Collecting RITA data for 2015, August
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-08.zip in 0.057203 seconds
# ('2015-08.zip', <httplib.HTTPMessage instance at 0x1044d2cf8>)
# Unzipping 2015-08.zip
# RITA file is: 2015-08.csv
# 2015
# 9
# Collecting RITA data for 2015, September
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-09.zip in 0.059656 seconds
# ('2015-09.zip', <httplib.HTTPMessage instance at 0x1044d2b48>)
# Unzipping 2015-09.zip
# RITA file is: 2015-09.csv
# 2015
# 10
# Collecting RITA data for 2015, October
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-10.zip in 0.060973 seconds
# ('2015-10.zip', <httplib.HTTPMessage instance at 0x1044d2170>)
# Unzipping 2015-10.zip
# RITA file is: 2015-10.csv
# 2015
# 11
# Collecting RITA data for 2015, November
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-11.zip in 0.058702 seconds
# ('2015-11.zip', <httplib.HTTPMessage instance at 0x1044d2320>)
# Unzipping 2015-11.zip
# RITA file is: 2015-11.csv
# 2015
# 12
# Collecting RITA data for 2015, December
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2015-12.zip in 0.096599 seconds
# ('2015-12.zip', <httplib.HTTPMessage instance at 0x1044d2b48>)
# Unzipping 2015-12.zip
# RITA file is: 2015-12.csv
# 2016
# 1
# Collecting RITA data for 2016, January
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2016-01.zip in 0.045256 seconds
# ('2016-01.zip', <httplib.HTTPMessage instance at 0x1044d2248>)
# Unzipping 2016-01.zip
# RITA file is: 2016-01.csv
# 2016
# 2
# Collecting RITA data for 2016, February
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2016-02.zip in 0.040876 seconds
# ('2016-02.zip', <httplib.HTTPMessage instance at 0x1044d20e0>)
# Unzipping 2016-02.zip
# RITA file is: 2016-02.csv
# 2016
# 3
# Collecting RITA data for 2016, March
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2016-03.zip in 0.04897 seconds
# ('2016-03.zip', <httplib.HTTPMessage instance at 0x1044d2128>)
# Unzipping 2016-03.zip
# RITA file is: 2016-03.csv
# 2016
# 4
# Collecting RITA data for 2016, April
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2016-04.zip in 0.050863 seconds
# ('2016-04.zip', <httplib.HTTPMessage instance at 0x10458aef0>)
# Unzipping 2016-04.zip
# RITA file is: 2016-04.csv
# 2016
# 5
# Collecting RITA data for 2016, May
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2016-05.zip in 0.062415 seconds
# ('2016-05.zip', <httplib.HTTPMessage instance at 0x1044d20e0>)
# Unzipping 2016-05.zip
# RITA file is: 2016-05.csv
# 2016
# 6
# Collecting RITA data for 2016, June
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2016-06.zip in 0.06365 seconds
# ('2016-06.zip', <httplib.HTTPMessage instance at 0x10458af80>)
# Unzipping 2016-06.zip
# RITA file is: 2016-06.csv
# 2016
# 7
# Collecting RITA data for 2016, July
# Sending POST to www.transtats.bts.gov
# get the response from the POST
# Downloaded: 2016-07.zip in 0.065945 seconds
# ('2016-07.zip', <httplib.HTTPMessage instance at 0x1044d2a28>)
# Unzipping 2016-07.zip
# RITA file is: 2016-07.csv
