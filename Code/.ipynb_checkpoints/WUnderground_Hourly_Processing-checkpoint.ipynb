# %%
import pandas as pd
from datetime import date, datetime, timedelta
from time import sleep
import html5lib
import string
import os

# %% [markdown]
# ## Clean Hourly Weather Data

# %%
columns = ['Time (CST)', 'Temp', 'Dew Point', 'Humidity', 
           'Pressure', 'Visibility', 'Wind Dir', 'Wind Speed', 'Gust Speed', 
           'Precip', 'Events', 'Conditions', 'Airport', 'Date']

# %%
df = pd.read_csv('../Assets/Datasets/Weather/Weather_Hourly_2016125129.csv', names=columns)

# %%
# remove windchill and gust speed. too many null values
df = df.drop(['Gust Speed'], axis=1)

# %%
# Format time to match BTS time (24hr int)
# add hours column
def get_hour(x):
    hour = str(x[0])
    signal = x[1].split(' ')[1]
    if signal == 'AM' and hour == '12':
        hour = '00'
    if signal == 'PM' and hour != '12':
        hour = str(int(hour) + 12)
    return int(hour)

def get_time(x):
    hour = str(x[0])
    minute = x[1].split(' ')[0]
    signal = x[1].split(' ')[1]
    if signal == 'AM' and hour == '12':
        hour = '00'
    if signal == 'PM' and hour != '12':
        hour = str(int(hour) + 12)
    return int(hour+minute)

df['Hour'] = df['Time (CST)'].str.split(':').apply(lambda x: get_hour(x))
df['Time (CST)'] = df['Time (CST)'].str.split(':').apply(lambda x: get_time(x))

# %%
# Drop duplicate rows for airport, date, hour
df.drop_duplicates(subset=['Airport', 'Date', 'Hour'], inplace=True)

# %%
columns = df.columns

# %%
# remove non-ascii characters
printable = set(string.printable)
def clean_cell(cell):
    cell = str(cell)
    return filter(lambda x: x in printable, cell)
    
for column in columns:
    df[column] = df[column].apply(lambda x: clean_cell(x))

# %%
# null values for precip and events become 0 and No_Event
df['Precip'] = df['Precip'].apply(lambda x: 0 if x in ['nan', 'T'] else x)
df['Events'] = df['Events'].apply(lambda x: 'No_Event' if x == 'nan' else x)

# %%
# remove non-numeric characters
num_columns = ['Hour', 'Time (CST)', 'Temp', 'Dew Point', 'Humidity', 'Pressure', 'Visibility', 'Wind Speed',
              'Precip']

def num_only(x):
    x = str(x)
    new_x = ''
    for char in x:
        if char.isdigit() or char == '.':
            new_x += char
    return new_x

for column in num_columns:
    df[column] = df[column].apply(lambda x: num_only(x))

# %%
# Change types
for column in num_columns:
    df[column] = df[column].apply(pd.to_numeric)

# %%
# Add 4-hour dayparts
def daypart(x):
    if x < 4:
        return 'red_eye'
    elif x < 8:
        return 'early_morning'
    elif x < 12:
        return 'morning'
    elif x < 16:
        return 'afternoon'
    elif x < 20:
        return 'evening'
    else:
        return 'night'
            
df['Daypart'] = df['Hour'].apply(lambda x: daypart(x))

# %%
# When Wind Dir is Calm, Wind speed is also calm
# Replace wind speed as 0 if wind dir is calm
df['Wind Speed'] = df.apply(lambda row: (0 if row['Wind Dir'] == 'Calm' else row['Wind Speed']), axis=1)

# %%
df
# Out:
#         Time (CST)  Temp  Dew Point  Humidity  Pressure  Visibility Wind Dir  \
# 0              251  37.9       25.0      60.0     29.78        10.0      WSW
# 1              351  36.0       26.1      67.0     29.78        10.0       SW
# 2              451  33.1       25.0      72.0     29.79        10.0      WSW
# 3              551  30.9       21.9      69.0     29.81        10.0      WSW
# 4              648  30.2       21.2      69.0     29.80        10.0      WSW
# 6              751  28.0       17.1      63.0     29.85        10.0      WSW
# 7              851  26.1       14.0      60.0     29.90        10.0      WSW
# 8              951  24.1       10.0      55.0     29.93        10.0      WSW
# 9             1051  21.9        8.1      55.0     29.94        10.0      WSW
# 10            1151  21.0        7.0      55.0     29.94        10.0      WSW
# 11            1251  21.9        7.0      53.0     29.94        10.0      WSW
# 12            1351  21.9        6.1      51.0     29.96        10.0      WSW
# 13            1451  19.9        5.0      52.0     29.99        10.0      WSW
# 14            1551  19.9        5.0      52.0     30.02        10.0     West
# 15            1651  19.9        3.9      50.0     30.06        10.0     West
# 16            1751  19.0        3.9      52.0     30.09        10.0      WSW
# 17            1851  18.0        3.9      54.0     30.12         9.0     West
# 18            1951  17.1        3.0      54.0     30.14        10.0     West
# 19            2051  17.1        3.9      56.0     30.14        10.0      WSW
# 20            2151  16.0        3.0      57.0     30.17        10.0      WSW
# 21            2251  16.0        6.1      65.0     30.18        10.0      WSW
# 22            2351  15.1        3.9      61.0     30.18        10.0      WSW
# 23              51  21.9       14.0      72.0     30.16        10.0    South
# 24             151  21.9       14.0      72.0     30.15        10.0      SSW
# 25             251  21.9       14.0      72.0     30.14        10.0      SSW
# 26             351  21.9       14.0      72.0     30.14        10.0      SSW
# 27             451  23.0       14.0      68.0     30.12        10.0      SSW
# 28             551  23.0       14.0      68.0     30.07        10.0      SSW
# 29             651  23.0       14.0      68.0     30.13        10.0       SW
# 30             751  24.1       14.0      65.0     30.13        10.0       SW
# ...            ...   ...        ...       ...       ...         ...      ...
# 123200        1851  68.0       44.1      42.0     29.98        10.0     West
# 123201        1951  66.0       45.0      47.0     29.99        10.0     West
# 123202        2051  64.9       46.0      50.0     29.99        10.0     West
# 123203        2151  63.0       46.9      56.0     30.01        10.0     West
# 123204        2251  62.1       48.0      60.0     30.02        10.0      WSW
# 123205        2351  63.0       48.9      60.0     30.02        10.0      WSW
# 123206          53  35.1       30.9      85.0     29.69        10.0     East
# 123207         116  35.1       30.9      85.0     29.67        10.0     East
# 123209         253  34.0       30.9      89.0     29.70         6.0       NE
# 123210         318  34.0       30.9      89.0     29.67         7.0      ENE
# 123213         453  36.0       33.1      89.0     29.73         6.0      NNE
# 123214         553  37.0       34.0      89.0     29.73         6.0       NE
# 123215         624  37.0       34.0      89.0     29.72         6.0      ENE
# 123217         710  37.0       34.0      89.0     29.72         7.0       NE
# 123220         851  33.8       32.0      93.0     29.75         1.5       NE
# 123222         953  34.0       32.0      92.0     29.80         1.2       NE
# 123223        1038  34.0       32.0      92.0     29.78         2.5       NE
# 123225        1147  33.8       30.2      87.0     29.79         1.5       NE
# 123227        1248  32.0       28.4      87.0     29.80         2.0       NE
# 123229        1313  30.9       28.0      89.0     29.80         3.0       NE
# 123232        1448  28.4       26.6      93.0     29.84         1.0       NE
# 123234        1517  28.9       24.1      82.0     29.86         4.0      NNE
# 123236        1653  28.9       19.9      69.0     29.94        10.0      NNE
# 123237        1753  28.9       19.9      69.0     29.97        10.0      NNE
# 123238        1853  28.9       19.0      67.0     29.99        10.0       NE
# 123239        1953  28.0       18.0      66.0     30.00        10.0      NNE
# 123240        2053  28.0       18.0      66.0     30.01        10.0      NNE
# 123241        2153  27.0       18.0      69.0     30.02        10.0      NNE
# 123242        2253  27.0       18.0      69.0     30.02        10.0      NNE
# 123243        2353  26.1       17.1      69.0     30.01        10.0      ENE
#
#         Wind Speed  Precip         Events        Conditions Airport  \
# 0             11.5    0.00       No_Event          Overcast    KMDW
# 1             13.8    0.00       No_Event     Mostly Cloudy    KMDW
# 2             17.3    0.00       No_Event  Scattered Clouds    KMDW
# 3             16.1    0.00       No_Event  Scattered Clouds    KMDW
# 4             16.1    0.00       No_Event     Mostly Cloudy    KMDW
# 6             16.1    0.00       No_Event     Mostly Cloudy    KMDW
# 7             16.1    0.00       No_Event          Overcast    KMDW
# 8             23.0    0.00       No_Event          Overcast    KMDW
# 9             21.9    0.00       No_Event          Overcast    KMDW
# 10            20.7    0.00       No_Event     Mostly Cloudy    KMDW
# 11            20.7    0.00       No_Event  Scattered Clouds    KMDW
# 12            24.2    0.00       No_Event     Mostly Cloudy    KMDW
# 13            25.3    0.00       No_Event     Mostly Cloudy    KMDW
# 14            25.3    0.00       No_Event          Overcast    KMDW
# 15            24.2    0.00       No_Event          Overcast    KMDW
# 16            18.4    0.00       No_Event          Overcast    KMDW
# 17            20.7    0.00       No_Event  Scattered Clouds    KMDW
# 18            19.6    0.00       No_Event  Scattered Clouds    KMDW
# 19            17.3    0.00       No_Event          Overcast    KMDW
# 20            19.6    0.00       No_Event          Overcast    KMDW
# 21            15.0    0.00       No_Event          Overcast    KMDW
# 22            17.3    0.00       No_Event  Scattered Clouds    KMDW
# 23             9.2    0.00       No_Event             Clear    KMDW
# 24             8.1    0.00       No_Event             Clear    KMDW
# 25             8.1    0.00       No_Event             Clear    KMDW
# 26             6.9    0.00       No_Event             Clear    KMDW
# 27             8.1    0.00       No_Event             Clear    KMDW
# 28             8.1    0.00       No_Event             Clear    KMDW
# 29             6.9    0.00       No_Event     Partly Cloudy    KMDW
# 30             5.8    0.00       No_Event  Scattered Clouds    KMDW
# ...            ...     ...            ...               ...     ...
# 123200         9.2    0.00       No_Event  Scattered Clouds    KMDW
# 123201         6.9    0.00       No_Event  Scattered Clouds    KMDW
# 123202         5.8    0.00       No_Event     Partly Cloudy    KMDW
# 123203         5.8    0.00       No_Event     Partly Cloudy    KMDW
# 123204         6.9    0.00       No_Event     Mostly Cloudy    KMDW
# 123205         6.9    0.00       No_Event          Overcast    KMDW
# 123206         5.8    0.00       No_Event          Overcast    KMDW
# 123207         6.9    0.00       No_Event          Overcast    KMDW
# 123209         8.1    0.00       No_Event          Overcast    KMDW
# 123210         8.1    0.00       No_Event          Overcast    KMDW
# 123213         6.9    0.00       No_Event          Overcast    KMDW
# 123214         9.2    0.00       No_Event          Overcast    KMDW
# 123215        11.5    0.00       No_Event          Overcast    KMDW
# 123217        15.0    0.00           Rain        Light Rain    KMDW
# 123220        18.4    0.02  Rain \t, Snow        Light Rain    KMDW
# 123222        20.7    0.01           Snow        Light Snow    KMDW
# 123223        20.7    0.01           Snow        Light Snow    KMDW
# 123225        13.8    0.00           Snow        Light Snow    KMDW
# 123227        18.4    0.00           Snow        Light Snow    KMDW
# 123229        19.6    0.00           Snow        Light Snow    KMDW
# 123232        19.6    0.00           Snow        Light Snow    KMDW
# 123234        23.0    0.00           Snow        Light Snow    KMDW
# 123236        21.9    0.00       No_Event          Overcast    KMDW
# 123237        18.4    0.00           Snow        Light Snow    KMDW
# 123238        16.1    0.00       No_Event          Overcast    KMDW
# 123239        16.1    0.00       No_Event     Mostly Cloudy    KMDW
# 123240        17.3    0.00       No_Event     Mostly Cloudy    KMDW
# 123241        16.1    0.00       No_Event     Mostly Cloudy    KMDW
# 123242        15.0    0.00       No_Event          Overcast    KMDW
# 123243        13.8    0.00       No_Event     Mostly Cloudy    KMDW
#
#               Date  Hour        Daypart
# 0       2011-01-01     2        red_eye
# 1       2011-01-01     3        red_eye
# 2       2011-01-01     4  early_morning
# 3       2011-01-01     5  early_morning
# 4       2011-01-01     6  early_morning
# 6       2011-01-01     7  early_morning
# 7       2011-01-01     8        morning
# 8       2011-01-01     9        morning
# 9       2011-01-01    10        morning
# 10      2011-01-01    11        morning
# 11      2011-01-01    12      afternoon
# 12      2011-01-01    13      afternoon
# 13      2011-01-01    14      afternoon
# 14      2011-01-01    15      afternoon
# 15      2011-01-01    16        evening
# 16      2011-01-01    17        evening
# 17      2011-01-01    18        evening
# 18      2011-01-01    19        evening
# 19      2011-01-01    20          night
# 20      2011-01-01    21          night
# 21      2011-01-01    22          night
# 22      2011-01-01    23          night
# 23      2011-01-03     0        red_eye
# 24      2011-01-03     1        red_eye
# 25      2011-01-03     2        red_eye
# 26      2011-01-03     3        red_eye
# 27      2011-01-03     4  early_morning
# 28      2011-01-03     5  early_morning
# 29      2011-01-03     6  early_morning
# 30      2011-01-03     7  early_morning
# ...            ...   ...            ...
# 123200  2013-07-28    18        evening
# 123201  2013-07-28    19        evening
# 123202  2013-07-28    20          night
# 123203  2013-07-28    21          night
# 123204  2013-07-28    22          night
# 123205  2013-07-28    23          night
# 123206  2015-01-25     0        red_eye
# 123207  2015-01-25     1        red_eye
# 123209  2015-01-25     2        red_eye
# 123210  2015-01-25     3        red_eye
# 123213  2015-01-25     4  early_morning
# 123214  2015-01-25     5  early_morning
# 123215  2015-01-25     6  early_morning
# 123217  2015-01-25     7  early_morning
# 123220  2015-01-25     8        morning
# 123222  2015-01-25     9        morning
# 123223  2015-01-25    10        morning
# 123225  2015-01-25    11        morning
# 123227  2015-01-25    12      afternoon
# 123229  2015-01-25    13      afternoon
# 123232  2015-01-25    14      afternoon
# 123234  2015-01-25    15      afternoon
# 123236  2015-01-25    16        evening
# 123237  2015-01-25    17        evening
# 123238  2015-01-25    18        evening
# 123239  2015-01-25    19        evening
# 123240  2015-01-25    20          night
# 123241  2015-01-25    21          night
# 123242  2015-01-25    22          night
# 123243  2015-01-25    23          night
#
# [97612 rows x 15 columns]

# %%
df.isnull().sum()
# Out:
# Time (CST)     0
# Temp          11
# Dew Point     13
# Humidity      14
# Pressure      18
# Visibility    16
# Wind Dir       0
# Wind Speed    16
# Precip         0
# Events         0
# Conditions     0
# Airport        0
# Date           0
# Hour           0
# Daypart        0
# dtype: int64

# %%
df.dropna(inplace=True)
df.shape
# Out:
# (97575, 15)

# %% [markdown]
# ## Error Checking

# %%
# Create table of all expected Airport, Date, Hours
def date_range(start, end):
    dates = []
    curr = start
    while curr <= end:
        dates.append(curr)
        curr += timedelta(days=1)
    return dates

airports = ['KMDW', 'KORD']
start_date = date(2011, 1, 1)
end_date = date(2016, 7, 31)
dates = date_range(start_date, end_date)
hours = range(0, 24)

table = []
for airport in airports:
    for date in dates:
        for hour in hours:
            table.append([airport, date, hour])

table = pd.DataFrame(table)
table.columns = ['Airport', 'Date', 'Hour']
table['Hour'] = table['Hour'].astype(int)
table['Year'] = table['Date'].apply(lambda x: str(x.year))
table['Month'] = table['Date'].apply(lambda x: str(x.month))
table['Month'] = table['Month'].apply(lambda x: x if len(str(x)) == 2 else '0'+ x)
table['Day'] = table['Date'].apply(lambda x: str(x.day))
table['Day'] = table['Day'].apply(lambda x: x if len(str(x)) == 2 else '0'+ x)
table['Date'] = table['Year'] + '-' + table['Month'] + '-' + table['Day']

# %%
# Find rows in table, not in df
match = pd.merge(table[['Airport', 'Date', 'Hour']], df, on= ['Airport', 'Date', 'Hour'], how='left')
missing = match[match['Time (CST)'].isnull()]
missing.shape

# %%
# Summarize missing hours per airport & day
missing.groupby(['Airport', 'Date'])['Hour'].count().sort_values(ascending=False)
# Out:
# Airport  Date
# KMDW     2015-06-17    5
# KORD     2015-06-17    5
# KMDW     2014-05-06    4
#          2011-02-17    4
# KORD     2013-01-19    4
#          2014-05-06    4
#          2014-02-12    3
#          2014-08-03    3
#          2014-07-26    3
#          2014-05-19    3
# KMDW     2014-07-26    3
# KORD     2014-01-27    3
#          2014-09-06    3
# KMDW     2014-08-13    3
# KORD     2012-12-20    3
# KMDW     2015-10-02    3
# KORD     2014-08-13    3
# KMDW     2016-01-04    3
# KORD     2015-10-02    3
#          2016-01-04    3
# KMDW     2011-12-09    2
# KORD     2012-12-17    2
#          2014-06-28    2
#          2014-06-12    2
#          2014-06-09    2
#          2014-02-27    2
#          2015-10-03    2
# KMDW     2014-05-19    2
# KORD     2013-02-19    2
#          2013-01-17    2
#                       ..
#          2011-07-24    1
#          2011-06-07    1
#          2011-05-28    1
#          2011-05-12    1
#          2011-03-13    1
#          2011-01-01    1
# KMDW     2016-07-06    1
# KORD     2012-10-01    1
#          2012-10-02    1
#          2012-10-12    1
#          2013-03-10    1
#          2013-12-21    1
#          2013-11-17    1
#          2013-11-03    1
#          2013-08-15    1
#          2013-07-02    1
#          2013-06-24    1
#          2013-03-18    1
#          2013-03-16    1
#          2013-03-05    1
#          2012-10-15    1
#          2013-02-17    1
#          2013-02-05    1
#          2013-01-30    1
#          2013-01-16    1
#          2012-12-26    1
#          2012-12-05    1
#          2012-11-17    1
#          2012-11-04    1
#          2011-11-11    1
# Name: Hour, dtype: int64

# %% [markdown]
# ## Export Final

# %%
df.to_csv('../Assets/Datasets/Weather/Clean_Weather_Hourly.csv', index=False)
